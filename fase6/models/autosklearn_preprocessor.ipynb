# %%
import pandas as pd
pd.set_option('display.max_columns', None)

train = pd.read_csv('../data/train_data.csv')
test = pd.read_csv('../data/test_data.csv')

# %%
# Vamos a definir los datos de entrenamiento
X = train.drop(['mineralType', 'id'], axis=1)
y = train['mineralType']

# %%
X['planetSection'] = X['planetSection'].astype('category')
X['geoZone'] = X['geoZone'].astype('category')
X['rockSize'] = X['rockSize'].astype('category')
X['cover'] = X['cover'].astype('category')
X['magmaConcentrationDistance'] = X['magmaConcentrationDistance'].astype('category')

# %%
from autosklearn.experimental.askl2 import AutoSklearn2Classifier
from autosklearn.classification import AutoSklearnClassifier
from autosklearn.metrics import accuracy

# Create sklearn pipeline for data preprocessing
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer, OneHotEncoder, OrdinalEncoder, StandardScaler, RobustScaler
from sklearn.feature_extraction import FeatureHasher
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer, IterativeImputer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import LinearSVC
from sklearn.neural_network import MLPClassifier
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, make_scorer, recall_score, precision_score
from sklearn.decomposition import PCA, NMF
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn import set_config
import numpy as np
import mlflow
import math
from joblib import Memory
from shutil import rmtree

mlflow.sklearn.autolog()
mlflow.set_experiment("autosklearn_preprocessor")

preprocessor = ColumnTransformer([
        # (name, transformer, columns)
        ("temperatureFirstHalfPlanetRotation", make_pipeline(IterativeImputer(missing_values=-999.0), FunctionTransformer(lambda f: (f - 32) / 1.8, feature_names_out="one-to-one"), RobustScaler()), ['temperatureFirstHalfPlanetRotation']), # convert from Fahrenheit to Celsius
        ("temperatureSecondHalfPlanetRotation", StandardScaler(), ['temperatureSecondHalfPlanetRotation']), # pass through the column unchanged
        ("waterStreamDistanceX", make_pipeline(FunctionTransformer(lambda f: f * 0.3048, feature_names_out="one-to-one"), StandardScaler()), ['waterStreamDistanceX']), # convert from feet to meters
        ("waterStreamDistanceY", StandardScaler(), ['waterStreamDistanceY']), # pass through the column unchanged
        ("planetSection", OneHotEncoder(handle_unknown = "ignore"), ['planetSection']), # one-hot encode the planetSection column
        ("cover", OneHotEncoder(handle_unknown='error', drop='first'), ['cover']), # one-hot encode the cover column and drop the first column (the one with the missing values == 0)
        ("climaticZone", OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1), ['climaticZone']), # ordinal encode the climaticZone column TODO: drop category 3? what to do? only one row has a 3
        ("geoZone", OneHotEncoder(handle_unknown = "ignore"), ['geoZone']), # one-hot encode the geoZone column TODO: drop category 5?
        ("rockSize", OneHotEncoder(handle_unknown='ignore', drop='first'), ['rockSize']), # one-hot encode the rockSize column and drop the first column (the one with the missing values == 0)
        ("magmaConcentrationDistance", OneHotEncoder(handle_unknown = "ignore"), ['magmaConcentrationDistance']), # one-hot encode the rockSize column and drop the first column (the one with the missing values == 0) TODO: use Ordinal Encoder?
        ("mineralDensity", make_pipeline(IterativeImputer(missing_values=-999.0), RobustScaler()), ['mineralDensity']), # pass through the column unchanged
        ("detectionDepth", StandardScaler(), ['detectionDepth']), # pass through the column unchanged TODO: convert km to m?
        ("longitude", StandardScaler(), ['longitude']), # pass through the column unchanged TODO: values > 360? do x - 360
    ],
    verbose_feature_names_out=False, remainder='passthrough'
)

def euclidean_distance(x, y):
    res = []
    for i in range(len(x)):
        res.append(math.sqrt(x[i]**2 + y[i]**2))
    return np.array(res)

class CreateVariables(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
        
    def fit(self, X, y = None):
        return self

    def transform(self, X, y = None):
        # waterSteamDistance
        waterStreamDistanceX = X[:,2]
        waterStreamDistanceY = X[:,3]
        waterStreamDistance = euclidean_distance(waterStreamDistanceX, waterStreamDistanceY)
        X = np.append(X, waterStreamDistance.reshape(-1, 1), axis=1)

        # temperature (both planet rotations)
        temperatureFirstHalfPlanetRotation = X[:,0]
        temperatureSecondHalfPlanetRotation = X[:,1]
        meanTemperature = (temperatureFirstHalfPlanetRotation + temperatureSecondHalfPlanetRotation)/2
        X = np.append(X, meanTemperature.reshape(-1, 1), axis=1)

        return X

pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('create_variables', CreateVariables()),
    # ('pca', PCA()),
    # ('model', AutoSklearn2Classifier(n_jobs=-1, metric=accuracy, time_left_for_this_task=60,
    #             # include={
    #             #     'data_preprocessor': ['NoPreprocessing']
    #             # }
    #          )
    # )
])

cls = AutoSklearn2Classifier(n_jobs=-1, metric=accuracy, time_left_for_this_task=1200)
cls.fit(pipe.fit_transform(X), y)
# Out:
# 2022/04/28 20:45:22 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2022/04/28 20:45:22 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '8e201c87a4d94a4482013f47f900e731', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2022/04/28 20:45:22 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `[('preprocessor', ColumnTransformer(remainder='passthrough',
#                   transformers=[('temperatureFirstHalfPlanetRotation',
#                                  Pipeline(steps=[('iterativeimputer',
#                                              ...`
# 2022/04/28 20:45:22 WARNING mlflow.utils: Truncated the value of the key `preprocessor`. Truncated value: `ColumnTransformer(remainder='passthrough',
#                   transformers=[('temperatureFirstHalfPlanetRotation',
#                                  Pipeline(steps=[('iterativeimputer',
#                                                   IterativeImpu...`
# 2022/04/28 20:45:22 WARNING mlflow.utils: Truncated the value of the key `preprocessor__transformers`. Truncated value: `[('temperatureFirstHalfPlanetRotation', Pipeline(steps=[('iterativeimputer', IterativeImputer(missing_values=-999.0)),
#                 ('functiontransformer',
#                  FunctionTransformer(feature_names_out='one-to-one',
#                    ...`
# 2022/04/28 20:45:22 WARNING mlflow.utils: Truncated the value of the key `preprocessor__temperatureFirstHalfPlanetRotation`. Truncated value: `Pipeline(steps=[('iterativeimputer', IterativeImputer(missing_values=-999.0)),
#                 ('functiontransformer',
#                  FunctionTransformer(feature_names_out='one-to-one',
#                                      func=<function <lambda...`
# 2022/04/28 20:45:22 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2022/04/28 20:45:22 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not specify a `predict` function, which is required in order to infer the signature
# /home/acampillos/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 40007 instead
#   f"Port {expected} is already in use.\n"
# [WARNING] [2022-04-28 20:45:29,931:Client-AutoML(1):5f988b70-c723-11ec-b75c-1314a69f1795] Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (1199.789170)
# [WARNING] [2022-04-28 20:45:29,931:Client-AutoML(1):5f988b70-c723-11ec-b75c-1314a69f1795] Capping the per_run_time_limit to 599.0 to have time for a least 2 models in each process.
# AutoSklearn2Classifier(metric=accuracy, n_jobs=-1, per_run_time_limit=2880,
#                        time_left_for_this_task=1200)

# %%
cls.sprint_statistics()
# Out:
# 'auto-sklearn results:\n  Dataset name: 5f988b70-c723-11ec-b75c-1314a69f1795\n  Metric: accuracy\n  Best validation score: 0.762301\n  Number of target algorithm runs: 228\n  Number of successful target algorithm runs: 223\n  Number of crashed target algorithm runs: 2\n  Number of target algorithms that exceeded the time limit: 3\n  Number of target algorithms that exceeded the memory limit: 0\n'

# %%
cls.show_models()
# Out:
# {147: {'model_id': 147,
#   'rank': 1,
#   'cost': 0.23579748038982648,
#   'ensemble_weight': 0.18,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f302307bd50>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f30253c9f90>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f30253c9b50>,
#   'sklearn_classifier': None},
#  73: {'model_id': 73,
#   'rank': 2,
#   'cost': 0.2396006655574043,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f3025537c90>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f3025872810>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f3025872190>,
#   'sklearn_classifier': None},
#  123: {'model_id': 123,
#   'rank': 3,
#   'cost': 0.23960066555740434,
#   'ensemble_weight': 0.04,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f3027d7af10>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f3027ad3590>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f3027ad3d90>,
#   'sklearn_classifier': None},
#  86: {'model_id': 86,
#   'rank': 4,
#   'cost': 0.2405514618492988,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f302a488510>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f30257e0650>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f30257e05d0>,
#   'sklearn_classifier': None},
#  105: {'model_id': 105,
#   'rank': 5,
#   'cost': 0.24261152048173681,
#   'ensemble_weight': 0.1,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f30251bf990>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f3027e1c0d0>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f3027e1cbd0>,
#   'sklearn_classifier': None},
#  82: {'model_id': 82,
#   'rank': 6,
#   'cost': 0.24316615165200856,
#   'ensemble_weight': 0.04,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f303165ff90>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f302a41e950>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f302a41e8d0>,
#   'sklearn_classifier': None},
#  65: {'model_id': 65,
#   'rank': 7,
#   'cost': 0.24372078282228035,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f302528c750>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f30251c4510>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f30251c4c50>,
#   'sklearn_classifier': None},
#  64: {'model_id': 64,
#   'rank': 8,
#   'cost': 0.24427541399255212,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f3027bfdc90>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f302530c9d0>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f302530c1d0>,
#   'sklearn_classifier': None},
#  124: {'model_id': 124,
#   'rank': 9,
#   'cost': 0.2445131130655257,
#   'ensemble_weight': 0.04,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f30279b8150>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f3027907350>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f3027907dd0>,
#   'sklearn_classifier': None},
#  117: {'model_id': 117,
#   'rank': 10,
#   'cost': 0.24506774423579747,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f3027ca3190>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f302a345190>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f302a345c10>,
#   'sklearn_classifier': None},
#  102: {'model_id': 102,
#   'rank': 11,
#   'cost': 0.24736550194120907,
#   'ensemble_weight': 0.14,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f3025872e90>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f3023043510>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f3023043250>,
#   'sklearn_classifier': None},
#  58: {'model_id': 58,
#   'rank': 12,
#   'cost': 0.2487916963790508,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f302a39b350>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f30279f65d0>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f30279f6110>,
#   'sklearn_classifier': None},
#  54: {'model_id': 54,
#   'rank': 13,
#   'cost': 0.2548134062277157,
#   'ensemble_weight': 0.04,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f3022ebf0d0>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f3022e5fcd0>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f3022e5f6d0>,
#   'sklearn_classifier': None},
#  136: {'model_id': 136,
#   'rank': 14,
#   'cost': 0.2557642025196102,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f302534b650>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f3025321f90>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f3025321e50>,
#   'sklearn_classifier': None},
#  71: {'model_id': 71,
#   'rank': 15,
#   'cost': 0.25592266856825924,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f3022ea3e90>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f3022ef1a90>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f3022ef1a50>,
#   'sklearn_classifier': None},
#  80: {'model_id': 80,
#   'rank': 16,
#   'cost': 0.256477299738531,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f30279f2f10>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f3027947490>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f3027947f10>,
#   'sklearn_classifier': None},
#  120: {'model_id': 120,
#   'rank': 17,
#   'cost': 0.2580619602250218,
#   'ensemble_weight': 0.04,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f3027cbe190>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f30255f83d0>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f30255f81d0>,
#   'sklearn_classifier': None},
#  135: {'model_id': 135,
#   'rank': 18,
#   'cost': 0.25893352349259174,
#   'ensemble_weight': 0.2,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f3027e6a4d0>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f30278a2d10>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f3027ae85d0>,
#   'sklearn_classifier': None}}

# %%
cls.leaderboard()
# Out:
#           rank  ensemble_weight               type      cost    duration
# model_id
# 147          1             0.18        extra_trees  0.235797   49.625379
# 73           2             0.02        extra_trees  0.239601   47.705335
# 123          3             0.04        extra_trees  0.239601   52.236234
# 86           4             0.02        extra_trees  0.240551   52.646666
# 105          5             0.10        extra_trees  0.242612   57.811886
# 82           6             0.04        extra_trees  0.243166   90.985490
# 65           7             0.02      random_forest  0.243721   93.603288
# 64           8             0.02        extra_trees  0.244275   70.589938
# 124          9             0.04        extra_trees  0.244513   52.466038
# 117         10             0.02        extra_trees  0.245068   67.287893
# 102         11             0.14      random_forest  0.247366   66.042824
# 58          12             0.02        extra_trees  0.248792  136.693751
# 54          13             0.04        extra_trees  0.254813   34.276224
# 136         14             0.02  gradient_boosting  0.255764  302.030159
# 71          15             0.02  gradient_boosting  0.255923  449.023136
# 80          16             0.02        extra_trees  0.256477  130.889162
# 120         17             0.04      random_forest  0.258062  135.511924
# 135         18             0.20  gradient_boosting  0.258934  307.017582

# %%
pd.DataFrame(cls.cv_results_).sort_values(by=['rank_test_scores'], ascending=True).head(10)
# Out:
#      mean_test_score  mean_fit_time  \
# 145         0.764203      49.625379
# 110         0.760875      45.247256
# 71          0.760399      47.705335
# 121         0.760399      52.236234
# 84          0.759449      52.646666
# 120         0.759290      54.145325
# 12          0.758815      60.213800
# 79          0.757864      63.492494
# 103         0.757388      57.811886
# 80          0.756834      90.985490
#
#                                                 params  rank_test_scores  \
# 145  {'balancing:strategy': 'none', 'classifier:__c...                 1
# 110  {'balancing:strategy': 'none', 'classifier:__c...                 2
# 71   {'balancing:strategy': 'none', 'classifier:__c...                 3
# 121  {'balancing:strategy': 'weighting', 'classifie...                 3
# 84   {'balancing:strategy': 'none', 'classifier:__c...                 5
# 120  {'balancing:strategy': 'none', 'classifier:__c...                 6
# 12   {'balancing:strategy': 'weighting', 'classifie...                 7
# 79   {'balancing:strategy': 'none', 'classifier:__c...                 8
# 103  {'balancing:strategy': 'weighting', 'classifie...                 9
# 80   {'balancing:strategy': 'none', 'classifier:__c...                10
#
#       status  budgets param_balancing:strategy param_classifier:__choice__  \
# 145  Success      0.0                     none                 extra_trees
# 110  Success      0.0                     none                 extra_trees
# 71   Success      0.0                     none                 extra_trees
# 121  Success      0.0                weighting                 extra_trees
# 84   Success      0.0                     none                 extra_trees
# 120  Success      0.0                     none                 extra_trees
# 12   Success      0.0                weighting                 extra_trees
# 79   Success      0.0                     none                 extra_trees
# 103  Success      0.0                weighting                 extra_trees
# 80   Success      0.0                     none                 extra_trees
#
#     param_data_preprocessor:__choice__ param_feature_preprocessor:__choice__  \
# 145                       feature_type                      no_preprocessing
# 110                       feature_type                      no_preprocessing
# 71                        feature_type                      no_preprocessing
# 121                       feature_type                      no_preprocessing
# 84                        feature_type                      no_preprocessing
# 120                       feature_type                      no_preprocessing
# 12                        feature_type                      no_preprocessing
# 79                        feature_type                      no_preprocessing
# 103                       feature_type                      no_preprocessing
# 80                        feature_type                      no_preprocessing
#
#     param_classifier:extra_trees:bootstrap  \
# 145                                  False
# 110                                  False
# 71                                   False
# 121                                  False
# 84                                   False
# 120                                  False
# 12                                   False
# 79                                   False
# 103                                  False
# 80                                   False
#
#     param_classifier:extra_trees:criterion  \
# 145                                   gini
# 110                                   gini
# 71                                    gini
# 121                                   gini
# 84                                    gini
# 120                                   gini
# 12                                 entropy
# 79                                    gini
# 103                                   gini
# 80                                    gini
#
#     param_classifier:extra_trees:max_depth  \
# 145                                   None
# 110                                   None
# 71                                    None
# 121                                   None
# 84                                    None
# 120                                   None
# 12                                    None
# 79                                    None
# 103                                   None
# 80                                    None
#
#      param_classifier:extra_trees:max_features  \
# 145                                   0.599270
# 110                                   0.863752
# 71                                    0.898538
# 121                                   0.808444
# 84                                    0.883144
# 120                                   0.916318
# 12                                    0.958941
# 79                                    0.849693
# 103                                   0.934500
# 80                                    0.957224
#
#     param_classifier:extra_trees:max_leaf_nodes  \
# 145                                        None
# 110                                        None
# 71                                         None
# 121                                        None
# 84                                         None
# 120                                        None
# 12                                         None
# 79                                         None
# 103                                        None
# 80                                         None
#
#      param_classifier:extra_trees:min_impurity_decrease  \
# 145                                                0.0
# 110                                                0.0
# 71                                                 0.0
# 121                                                0.0
# 84                                                 0.0
# 120                                                0.0
# 12                                                 0.0
# 79                                                 0.0
# 103                                                0.0
# 80                                                 0.0
#
#      param_classifier:extra_trees:min_samples_leaf  \
# 145                                            1.0
# 110                                            2.0
# 71                                             1.0
# 121                                            1.0
# 84                                             1.0
# 120                                            2.0
# 12                                             1.0
# 79                                             2.0
# 103                                            1.0
# 80                                             1.0
#
#      param_classifier:extra_trees:min_samples_split  \
# 145                                             4.0
# 110                                             3.0
# 71                                              5.0
# 121                                             3.0
# 84                                              2.0
# 120                                             5.0
# 12                                              5.0
# 79                                              3.0
# 103                                             2.0
# 80                                             10.0
#
#      param_classifier:extra_trees:min_weight_fraction_leaf  \
# 145                                                0.0
# 110                                                0.0
# 71                                                 0.0
# 121                                                0.0
# 84                                                 0.0
# 120                                                0.0
# 12                                                 0.0
# 79                                                 0.0
# 103                                                0.0
# 80                                                 0.0
#
#     param_classifier:gradient_boosting:early_stop  \
# 145                                           NaN
# 110                                           NaN
# 71                                            NaN
# 121                                           NaN
# 84                                            NaN
# 120                                           NaN
# 12                                            NaN
# 79                                            NaN
# 103                                           NaN
# 80                                            NaN
#
#      param_classifier:gradient_boosting:l2_regularization  \
# 145                                                NaN
# 110                                                NaN
# 71                                                 NaN
# 121                                                NaN
# 84                                                 NaN
# 120                                                NaN
# 12                                                 NaN
# 79                                                 NaN
# 103                                                NaN
# 80                                                 NaN
#
#      param_classifier:gradient_boosting:learning_rate  \
# 145                                               NaN
# 110                                               NaN
# 71                                                NaN
# 121                                               NaN
# 84                                                NaN
# 120                                               NaN
# 12                                                NaN
# 79                                                NaN
# 103                                               NaN
# 80                                                NaN
#
#     param_classifier:gradient_boosting:loss  \
# 145                                     NaN
# 110                                     NaN
# 71                                      NaN
# 121                                     NaN
# 84                                      NaN
# 120                                     NaN
# 12                                      NaN
# 79                                      NaN
# 103                                     NaN
# 80                                      NaN
#
#      param_classifier:gradient_boosting:max_bins  \
# 145                                          NaN
# 110                                          NaN
# 71                                           NaN
# 121                                          NaN
# 84                                           NaN
# 120                                          NaN
# 12                                           NaN
# 79                                           NaN
# 103                                          NaN
# 80                                           NaN
#
#     param_classifier:gradient_boosting:max_depth  \
# 145                                          NaN
# 110                                          NaN
# 71                                           NaN
# 121                                          NaN
# 84                                           NaN
# 120                                          NaN
# 12                                           NaN
# 79                                           NaN
# 103                                          NaN
# 80                                           NaN
#
#      param_classifier:gradient_boosting:max_leaf_nodes  \
# 145                                                NaN
# 110                                                NaN
# 71                                                 NaN
# 121                                                NaN
# 84                                                 NaN
# 120                                                NaN
# 12                                                 NaN
# 79                                                 NaN
# 103                                                NaN
# 80                                                 NaN
#
#      param_classifier:gradient_boosting:min_samples_leaf  \
# 145                                                NaN
# 110                                                NaN
# 71                                                 NaN
# 121                                                NaN
# 84                                                 NaN
# 120                                                NaN
# 12                                                 NaN
# 79                                                 NaN
# 103                                                NaN
# 80                                                 NaN
#
#     param_classifier:gradient_boosting:scoring  \
# 145                                        NaN
# 110                                        NaN
# 71                                         NaN
# 121                                        NaN
# 84                                         NaN
# 120                                        NaN
# 12                                         NaN
# 79                                         NaN
# 103                                        NaN
# 80                                         NaN
#
#      param_classifier:gradient_boosting:tol param_classifier:mlp:activation  \
# 145                                     NaN                             NaN
# 110                                     NaN                             NaN
# 71                                      NaN                             NaN
# 121                                     NaN                             NaN
# 84                                      NaN                             NaN
# 120                                     NaN                             NaN
# 12                                      NaN                             NaN
# 79                                      NaN                             NaN
# 103                                     NaN                             NaN
# 80                                      NaN                             NaN
#
#      param_classifier:mlp:alpha param_classifier:mlp:batch_size  \
# 145                         NaN                             NaN
# 110                         NaN                             NaN
# 71                          NaN                             NaN
# 121                         NaN                             NaN
# 84                          NaN                             NaN
# 120                         NaN                             NaN
# 12                          NaN                             NaN
# 79                          NaN                             NaN
# 103                         NaN                             NaN
# 80                          NaN                             NaN
#
#      param_classifier:mlp:beta_1  param_classifier:mlp:beta_2  \
# 145                          NaN                          NaN
# 110                          NaN                          NaN
# 71                           NaN                          NaN
# 121                          NaN                          NaN
# 84                           NaN                          NaN
# 120                          NaN                          NaN
# 12                           NaN                          NaN
# 79                           NaN                          NaN
# 103                          NaN                          NaN
# 80                           NaN                          NaN
#
#     param_classifier:mlp:early_stopping  param_classifier:mlp:epsilon  \
# 145                                 NaN                           NaN
# 110                                 NaN                           NaN
# 71                                  NaN                           NaN
# 121                                 NaN                           NaN
# 84                                  NaN                           NaN
# 120                                 NaN                           NaN
# 12                                  NaN                           NaN
# 79                                  NaN                           NaN
# 103                                 NaN                           NaN
# 80                                  NaN                           NaN
#
#      param_classifier:mlp:hidden_layer_depth  \
# 145                                      NaN
# 110                                      NaN
# 71                                       NaN
# 121                                      NaN
# 84                                       NaN
# 120                                      NaN
# 12                                       NaN
# 79                                       NaN
# 103                                      NaN
# 80                                       NaN
#
#      param_classifier:mlp:learning_rate_init  \
# 145                                      NaN
# 110                                      NaN
# 71                                       NaN
# 121                                      NaN
# 84                                       NaN
# 120                                      NaN
# 12                                       NaN
# 79                                       NaN
# 103                                      NaN
# 80                                       NaN
#
#      param_classifier:mlp:n_iter_no_change  \
# 145                                    NaN
# 110                                    NaN
# 71                                     NaN
# 121                                    NaN
# 84                                     NaN
# 120                                    NaN
# 12                                     NaN
# 79                                     NaN
# 103                                    NaN
# 80                                     NaN
#
#      param_classifier:mlp:num_nodes_per_layer param_classifier:mlp:shuffle  \
# 145                                       NaN                          NaN
# 110                                       NaN                          NaN
# 71                                        NaN                          NaN
# 121                                       NaN                          NaN
# 84                                        NaN                          NaN
# 120                                       NaN                          NaN
# 12                                        NaN                          NaN
# 79                                        NaN                          NaN
# 103                                       NaN                          NaN
# 80                                        NaN                          NaN
#
#     param_classifier:mlp:solver  param_classifier:mlp:tol  \
# 145                         NaN                       NaN
# 110                         NaN                       NaN
# 71                          NaN                       NaN
# 121                         NaN                       NaN
# 84                          NaN                       NaN
# 120                         NaN                       NaN
# 12                          NaN                       NaN
# 79                          NaN                       NaN
# 103                         NaN                       NaN
# 80                          NaN                       NaN
#
#      param_classifier:passive_aggressive:C  \
# 145                                    NaN
# 110                                    NaN
# 71                                     NaN
# 121                                    NaN
# 84                                     NaN
# 120                                    NaN
# 12                                     NaN
# 79                                     NaN
# 103                                    NaN
# 80                                     NaN
#
#     param_classifier:passive_aggressive:average  \
# 145                                         NaN
# 110                                         NaN
# 71                                          NaN
# 121                                         NaN
# 84                                          NaN
# 120                                         NaN
# 12                                          NaN
# 79                                          NaN
# 103                                         NaN
# 80                                          NaN
#
#     param_classifier:passive_aggressive:fit_intercept  \
# 145                                               NaN
# 110                                               NaN
# 71                                                NaN
# 121                                               NaN
# 84                                                NaN
# 120                                               NaN
# 12                                                NaN
# 79                                                NaN
# 103                                               NaN
# 80                                                NaN
#
#     param_classifier:passive_aggressive:loss  \
# 145                                      NaN
# 110                                      NaN
# 71                                       NaN
# 121                                      NaN
# 84                                       NaN
# 120                                      NaN
# 12                                       NaN
# 79                                       NaN
# 103                                      NaN
# 80                                       NaN
#
#      param_classifier:passive_aggressive:tol  \
# 145                                      NaN
# 110                                      NaN
# 71                                       NaN
# 121                                      NaN
# 84                                       NaN
# 120                                      NaN
# 12                                       NaN
# 79                                       NaN
# 103                                      NaN
# 80                                       NaN
#
#     param_classifier:random_forest:bootstrap  \
# 145                                      NaN
# 110                                      NaN
# 71                                       NaN
# 121                                      NaN
# 84                                       NaN
# 120                                      NaN
# 12                                       NaN
# 79                                       NaN
# 103                                      NaN
# 80                                       NaN
#
#     param_classifier:random_forest:criterion  \
# 145                                      NaN
# 110                                      NaN
# 71                                       NaN
# 121                                      NaN
# 84                                       NaN
# 120                                      NaN
# 12                                       NaN
# 79                                       NaN
# 103                                      NaN
# 80                                       NaN
#
#     param_classifier:random_forest:max_depth  \
# 145                                      NaN
# 110                                      NaN
# 71                                       NaN
# 121                                      NaN
# 84                                       NaN
# 120                                      NaN
# 12                                       NaN
# 79                                       NaN
# 103                                      NaN
# 80                                       NaN
#
#      param_classifier:random_forest:max_features  \
# 145                                          NaN
# 110                                          NaN
# 71                                           NaN
# 121                                          NaN
# 84                                           NaN
# 120                                          NaN
# 12                                           NaN
# 79                                           NaN
# 103                                          NaN
# 80                                           NaN
#
#     param_classifier:random_forest:max_leaf_nodes  \
# 145                                           NaN
# 110                                           NaN
# 71                                            NaN
# 121                                           NaN
# 84                                            NaN
# 120                                           NaN
# 12                                            NaN
# 79                                            NaN
# 103                                           NaN
# 80                                            NaN
#
#      param_classifier:random_forest:min_impurity_decrease  \
# 145                                                NaN
# 110                                                NaN
# 71                                                 NaN
# 121                                                NaN
# 84                                                 NaN
# 120                                                NaN
# 12                                                 NaN
# 79                                                 NaN
# 103                                                NaN
# 80                                                 NaN
#
#      param_classifier:random_forest:min_samples_leaf  \
# 145                                              NaN
# 110                                              NaN
# 71                                               NaN
# 121                                              NaN
# 84                                               NaN
# 120                                              NaN
# 12                                               NaN
# 79                                               NaN
# 103                                              NaN
# 80                                               NaN
#
#      param_classifier:random_forest:min_samples_split  \
# 145                                               NaN
# 110                                               NaN
# 71                                                NaN
# 121                                               NaN
# 84                                                NaN
# 120                                               NaN
# 12                                                NaN
# 79                                                NaN
# 103                                               NaN
# 80                                                NaN
#
#      param_classifier:random_forest:min_weight_fraction_leaf  \
# 145                                                NaN
# 110                                                NaN
# 71                                                 NaN
# 121                                                NaN
# 84                                                 NaN
# 120                                                NaN
# 12                                                 NaN
# 79                                                 NaN
# 103                                                NaN
# 80                                                 NaN
#
#      param_classifier:sgd:alpha param_classifier:sgd:average  \
# 145                         NaN                          NaN
# 110                         NaN                          NaN
# 71                          NaN                          NaN
# 121                         NaN                          NaN
# 84                          NaN                          NaN
# 120                         NaN                          NaN
# 12                          NaN                          NaN
# 79                          NaN                          NaN
# 103                         NaN                          NaN
# 80                          NaN                          NaN
#
#     param_classifier:sgd:fit_intercept param_classifier:sgd:learning_rate  \
# 145                                NaN                                NaN
# 110                                NaN                                NaN
# 71                                 NaN                                NaN
# 121                                NaN                                NaN
# 84                                 NaN                                NaN
# 120                                NaN                                NaN
# 12                                 NaN                                NaN
# 79                                 NaN                                NaN
# 103                                NaN                                NaN
# 80                                 NaN                                NaN
#
#     param_classifier:sgd:loss param_classifier:sgd:penalty  \
# 145                       NaN                          NaN
# 110                       NaN                          NaN
# 71                        NaN                          NaN
# 121                       NaN                          NaN
# 84                        NaN                          NaN
# 120                       NaN                          NaN
# 12                        NaN                          NaN
# 79                        NaN                          NaN
# 103                       NaN                          NaN
# 80                        NaN                          NaN
#
#      param_classifier:sgd:tol  \
# 145                       NaN
# 110                       NaN
# 71                        NaN
# 121                       NaN
# 84                        NaN
# 120                       NaN
# 12                        NaN
# 79                        NaN
# 103                       NaN
# 80                        NaN
#
#     param_data_preprocessor:feature_type:categorical_transformer:categorical_encoding:__choice__  \
# 145                                        no_encoding
# 110                                        no_encoding
# 71                                    one_hot_encoding
# 121                                           encoding
# 84                                         no_encoding
# 120                                        no_encoding
# 12                                    one_hot_encoding
# 79                                    one_hot_encoding
# 103                                   one_hot_encoding
# 80                                            encoding
#
#     param_data_preprocessor:feature_type:categorical_transformer:category_coalescence:__choice__  \
# 145                                 minority_coalescer
# 110                                 minority_coalescer
# 71                                  minority_coalescer
# 121                                 minority_coalescer
# 84                                  minority_coalescer
# 120                                 minority_coalescer
# 12                                  minority_coalescer
# 79                                  minority_coalescer
# 103                                 minority_coalescer
# 80                                  minority_coalescer
#
#     param_data_preprocessor:feature_type:numerical_transformer:imputation:strategy  \
# 145                                             median
# 110                                               mean
# 71                                              median
# 121                                               mean
# 84                                                mean
# 120                                             median
# 12                                                mean
# 79                                                mean
# 103                                             median
# 80                                       most_frequent
#
#     param_data_preprocessor:feature_type:numerical_transformer:rescaling:__choice__  \
# 145                                             minmax
# 110                                             minmax
# 71                                         standardize
# 121                                             minmax
# 84                                       robust_scaler
# 120                                      robust_scaler
# 12                                              minmax
# 79                                quantile_transformer
# 103                                             minmax
# 80                                              minmax
#
#      param_classifier:gradient_boosting:n_iter_no_change  \
# 145                                                NaN
# 110                                                NaN
# 71                                                 NaN
# 121                                                NaN
# 84                                                 NaN
# 120                                                NaN
# 12                                                 NaN
# 79                                                 NaN
# 103                                                NaN
# 80                                                 NaN
#
#      param_classifier:gradient_boosting:validation_fraction  \
# 145                                                NaN
# 110                                                NaN
# 71                                                 NaN
# 121                                                NaN
# 84                                                 NaN
# 120                                                NaN
# 12                                                 NaN
# 79                                                 NaN
# 103                                                NaN
# 80                                                 NaN
#
#      param_classifier:mlp:validation_fraction  param_classifier:sgd:epsilon  \
# 145                                       NaN                           NaN
# 110                                       NaN                           NaN
# 71                                        NaN                           NaN
# 121                                       NaN                           NaN
# 84                                        NaN                           NaN
# 120                                       NaN                           NaN
# 12                                        NaN                           NaN
# 79                                        NaN                           NaN
# 103                                       NaN                           NaN
# 80                                        NaN                           NaN
#
#      param_classifier:sgd:eta0  param_classifier:sgd:l1_ratio  \
# 145                        NaN                            NaN
# 110                        NaN                            NaN
# 71                         NaN                            NaN
# 121                        NaN                            NaN
# 84                         NaN                            NaN
# 120                        NaN                            NaN
# 12                         NaN                            NaN
# 79                         NaN                            NaN
# 103                        NaN                            NaN
# 80                         NaN                            NaN
#
#      param_classifier:sgd:power_t  \
# 145                           NaN
# 110                           NaN
# 71                            NaN
# 121                           NaN
# 84                            NaN
# 120                           NaN
# 12                            NaN
# 79                            NaN
# 103                           NaN
# 80                            NaN
#
#      param_data_preprocessor:feature_type:categorical_transformer:category_coalescence:minority_coalescer:minimum_fraction  \
# 145                                           0.342078
# 110                                           0.240172
# 71                                            0.363305
# 121                                           0.238964
# 84                                            0.099632
# 120                                           0.024322
# 12                                            0.003691
# 79                                            0.182167
# 103                                           0.071448
# 80                                            0.010000
#
#      param_data_preprocessor:feature_type:numerical_transformer:rescaling:quantile_transformer:n_quantiles  \
# 145                                                NaN
# 110                                                NaN
# 71                                                 NaN
# 121                                                NaN
# 84                                                 NaN
# 120                                                NaN
# 12                                                 NaN
# 79                                               900.0
# 103                                                NaN
# 80                                                 NaN
#
#     param_data_preprocessor:feature_type:numerical_transformer:rescaling:quantile_transformer:output_distribution  \
# 145                                                NaN
# 110                                                NaN
# 71                                                 NaN
# 121                                                NaN
# 84                                                 NaN
# 120                                                NaN
# 12                                                 NaN
# 79                                              normal
# 103                                                NaN
# 80                                                 NaN
#
#      param_data_preprocessor:feature_type:numerical_transformer:rescaling:robust_scaler:q_max  \
# 145                                                NaN
# 110                                                NaN
# 71                                                 NaN
# 121                                                NaN
# 84                                            0.750000
# 120                                           0.774575
# 12                                                 NaN
# 79                                                 NaN
# 103                                                NaN
# 80                                                 NaN
#
#      param_data_preprocessor:feature_type:numerical_transformer:rescaling:robust_scaler:q_min
# 145                                                NaN
# 110                                                NaN
# 71                                                 NaN
# 121                                                NaN
# 84                                            0.250000
# 120                                           0.234249
# 12                                                 NaN
# 79                                                 NaN
# 103                                                NaN
# 80                                                 NaN

# %%
import pickle

# save model
with open('autosklearn_900.pkl', 'wb') as f:
    pickle.dump(cls, f)

# %%
import pickle

# load model and calculate accuracy
with open('autosklearn_900.pkl', 'rb') as f:
    cls = pickle.load(f)

# %%
from autosklearn.experimental.askl2 import AutoSklearn2Classifier
from autosklearn.classification import AutoSklearnClassifier
from autosklearn.metrics import accuracy

# Create sklearn pipeline for data preprocessing
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer, OneHotEncoder, OrdinalEncoder, StandardScaler, RobustScaler
from sklearn.feature_extraction import FeatureHasher
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer, IterativeImputer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import LinearSVC
from sklearn.neural_network import MLPClassifier
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, make_scorer, recall_score, precision_score
from sklearn.decomposition import PCA, NMF
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn import set_config
import numpy as np
import mlflow
import math
from joblib import Memory
from shutil import rmtree

# %%
preprocessor = ColumnTransformer([
        # (name, transformer, columns)
        ("temperatureFirstHalfPlanetRotation", make_pipeline(IterativeImputer(missing_values=-999.0), FunctionTransformer(lambda f: (f - 32) / 1.8, feature_names_out="one-to-one"), RobustScaler()), ['temperatureFirstHalfPlanetRotation']), # convert from Fahrenheit to Celsius
        ("temperatureSecondHalfPlanetRotation", StandardScaler(), ['temperatureSecondHalfPlanetRotation']), # pass through the column unchanged
        ("waterStreamDistanceX", make_pipeline(FunctionTransformer(lambda f: f * 0.3048, feature_names_out="one-to-one"), StandardScaler()), ['waterStreamDistanceX']), # convert from feet to meters
        ("waterStreamDistanceY", StandardScaler(), ['waterStreamDistanceY']), # pass through the column unchanged
        ("planetSection", OneHotEncoder(handle_unknown = "ignore"), ['planetSection']), # one-hot encode the planetSection column
        ("cover", OneHotEncoder(handle_unknown='error', drop='first'), ['cover']), # one-hot encode the cover column and drop the first column (the one with the missing values == 0)
        ("climaticZone", OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1), ['climaticZone']), # ordinal encode the climaticZone column TODO: drop category 3? what to do? only one row has a 3
        ("geoZone", OneHotEncoder(handle_unknown = "ignore"), ['geoZone']), # one-hot encode the geoZone column TODO: drop category 5?
        ("rockSize", OneHotEncoder(handle_unknown='ignore', drop='first'), ['rockSize']), # one-hot encode the rockSize column and drop the first column (the one with the missing values == 0)
        ("magmaConcentrationDistance", OneHotEncoder(handle_unknown = "ignore"), ['magmaConcentrationDistance']), # one-hot encode the rockSize column and drop the first column (the one with the missing values == 0) TODO: use Ordinal Encoder?
        ("mineralDensity", make_pipeline(IterativeImputer(missing_values=-999.0), RobustScaler()), ['mineralDensity']), # pass through the column unchanged
        ("detectionDepth", StandardScaler(), ['detectionDepth']), # pass through the column unchanged TODO: convert km to m?
        ("longitude", StandardScaler(), ['longitude']), # pass through the column unchanged TODO: values > 360? do x - 360
    ],
    verbose_feature_names_out=False, remainder='passthrough'
)

def euclidean_distance(x, y):
    res = []
    for i in range(len(x)):
        res.append(math.sqrt(x[i]**2 + y[i]**2))
    return np.array(res)

class CreateVariables(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
        
    def fit(self, X, y = None):
        return self

    def transform(self, X, y = None):
        # waterSteamDistance
        waterStreamDistanceX = X[:,2]
        waterStreamDistanceY = X[:,3]
        waterStreamDistance = euclidean_distance(waterStreamDistanceX, waterStreamDistanceY)
        X = np.append(X, waterStreamDistance.reshape(-1, 1), axis=1)

        # temperature (both planet rotations)
        temperatureFirstHalfPlanetRotation = X[:,0]
        temperatureSecondHalfPlanetRotation = X[:,1]
        meanTemperature = (temperatureFirstHalfPlanetRotation + temperatureSecondHalfPlanetRotation)/2
        X = np.append(X, meanTemperature.reshape(-1, 1), axis=1)

        return X

pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('create_variables', CreateVariables()),
    # ('pca', PCA()),
    # ('model', AutoSklearn2Classifier(n_jobs=-1, metric=accuracy, time_left_for_this_task=60,
    #             # include={
    #             #     'data_preprocessor': ['NoPreprocessing']
    #             # }
    #          )
    # )
])

cls.score(pipe.fit_transform(X), y)
# Out:
# 1.0

# %% [markdown]
# -------------------------

# %%
train = pd.read_csv('../data/train_data.csv')
test = pd.read_csv('../data/test_data.csv')

# %%
X = train.drop(['mineralType', 'id'], axis=1)
y = train['mineralType']

# %%
X['planetSection'] = X['planetSection'].astype('category')
X['geoZone'] = X['geoZone'].astype('category')
X['rockSize'] = X['rockSize'].astype('category')
X['cover'] = X['cover'].astype('category')
X['magmaConcentrationDistance'] = X['magmaConcentrationDistance'].astype('category')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2)

# %%
cls2 = AutoSklearn2Classifier(n_jobs=-1, metric=accuracy, time_left_for_this_task=300)
cls2.fit(pipe.fit_transform(X_train), y_train)
# Out:
# /home/acampillos/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 40777 instead
#   f"Port {expected} is already in use.\n"
# [WARNING] [2022-04-28 21:14:28,648:Client-AutoML(1):6b87a46e-c727-11ec-b0e2-1314a69f1795] Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.210469)
# [WARNING] [2022-04-28 21:14:28,648:Client-AutoML(1):6b87a46e-c727-11ec-b0e2-1314a69f1795] Capping the per_run_time_limit to 149.0 to have time for a least 2 models in each process.
# AutoSklearn2Classifier(metric=accuracy, n_jobs=-1, per_run_time_limit=720,
#                        time_left_for_this_task=300)

# %%
cls2.score(pipe.fit_transform(X_test), y_test)
# Out:
# 0.8194059405940594

# %%
cls2.score(pipe.fit_transform(X), y)
# Out:
# 0.833135250772522

# %%
cls2.score(pipe.fit_transform(X_train), y_train)
# Out:
# 0.8315174326465927

# %% [markdown]
# Prueba sobre el conjunto de datos PARA LA ENTREGA

# %%
X_submit = test.drop(['id'], axis=1)

X_submit['planetSection'] = X_submit['planetSection'].astype('category')
X_submit['geoZone'] = X_submit['geoZone'].astype('category')
X_submit['rockSize'] = X_submit['rockSize'].astype('category')
X_submit['cover'] = X_submit['cover'].astype('category')
X_submit['magmaConcentrationDistance'] = X_submit['magmaConcentrationDistance'].astype('category')

# %%
len(X_submit.columns)
# Out:
# 13

# %%
pipe.fit_transform(X_submit).shape
# Out:
# (2000, 28)

# %%
cls2.predict(pipe.fit_transform(X_submit))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_94434/2179389468.py in <module>
# ----> 1 cls2.predict(pipe.fit_transform(X_submit))
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/autosklearn/estimators.py in predict(self, X, batch_size, n_jobs)
#    1072
#    1073         """
# -> 1074         return super().predict(X, batch_size=batch_size, n_jobs=n_jobs)
#    1075
#    1076     def predict_proba(self, X, batch_size=None, n_jobs=1):
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/autosklearn/estimators.py in predict(self, X, batch_size, n_jobs)
#     528
#     529     def predict(self, X, batch_size=None, n_jobs=1):
# --> 530         return self.automl_.predict(X, batch_size=batch_size, n_jobs=n_jobs)
#     531
#     532     def predict_proba(self, X, batch_size=None, n_jobs=1):
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/autosklearn/automl.py in predict(self, X, batch_size, n_jobs)
#    2088     def predict(self, X, batch_size=None, n_jobs=1):
#    2089         predicted_probabilities = super().predict(X, batch_size=batch_size,
# -> 2090                                                   n_jobs=n_jobs)
#    2091
#    2092         if self.InputValidator is None or not self.InputValidator._is_fitted:
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/autosklearn/automl.py in predict(self, X, batch_size, n_jobs)
#    1432                 batch_size=batch_size
#    1433             )
# -> 1434             for identifier in self.ensemble_.get_selected_model_identifiers()
#    1435         )
#    1436
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1041             # remaining jobs.
#    1042             self._iterating = False
# -> 1043             if self.dispatch_one_batch(iterator):
#    1044                 self._iterating = self._original_iterator is not None
#    1045
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/autosklearn/automl.py in _model_predict(model, X, task, batch_size, logger)
#     146                 prediction = predict_func(X_, batch_size=batch_size)
#     147             else:
# --> 148                 prediction = predict_func(X_)
#     149
#     150     # Check that probability values lie between 0 and 1.
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     122
#     123             # lambda, but not partial, allows help() to work with update_wrapper
# --> 124             out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)  # noqa
#     125         else:
#     126
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/sklearn/ensemble/_voting.py in predict_proba(self, X)
#     406         check_is_fitted(self)
#     407         avg = np.average(
# --> 408             self._collect_probas(X), axis=0, weights=self._weights_not_none
#     409         )
#     410         return avg
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/sklearn/ensemble/_voting.py in _collect_probas(self, X)
#     381     def _collect_probas(self, X):
#     382         """Collect results from clf.predict calls."""
# --> 383         return np.asarray([clf.predict_proba(X) for clf in self.estimators_])
#     384
#     385     def _check_voting(self):
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/sklearn/ensemble/_voting.py in <listcomp>(.0)
#     381     def _collect_probas(self, X):
#     382         """Collect results from clf.predict calls."""
# --> 383         return np.asarray([clf.predict_proba(X) for clf in self.estimators_])
#     384
#     385     def _check_voting(self):
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/autosklearn/pipeline/classification.py in predict_proba(self, X, batch_size)
#     133         """
#     134         if batch_size is None:
# --> 135             return super().predict_proba(X)
#     136
#     137         else:
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     122
#     123             # lambda, but not partial, allows help() to work with update_wrapper
# --> 124             out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)  # noqa
#     125         else:
#     126
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/sklearn/pipeline.py in predict_proba(self, X, **predict_proba_params)
#     521         Xt = X
#     522         for _, name, transform in self._iter(with_final=False):
# --> 523             Xt = transform.transform(Xt)
#     524         return self.steps[-1][1].predict_proba(Xt, **predict_proba_params)
#     525
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/autosklearn/pipeline/components/data_preprocessing/__init__.py in transform(self, X)
#     127
#     128     def transform(self, X: PIPELINE_DATA_DTYPE) -> PIPELINE_DATA_DTYPE:
# --> 129         return self.choice.transform(X)
#     130
#     131     def set_hyperparameters(self, configuration: ConfigurationSpace,
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/autosklearn/pipeline/components/data_preprocessing/feature_type.py in transform(self, X)
#     156                              "while trying to fit the model."
#     157                              )
# --> 158         return self.column_transformer.transform(X)
#     159
#     160     @staticmethod
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py in transform(self, X)
#     744             # ndarray was used for fitting or transforming, thus we only
#     745             # check that n_features_in_ is consistent
# --> 746             self._check_n_features(X, reset=False)
#     747
#     748         Xs = self._fit_transform(
#
# ~/.pyenv/versions/3.7.13/envs/edrvass/lib/python3.7/site-packages/sklearn/base.py in _check_n_features(self, X, reset)
#     399         if n_features != self.n_features_in_:
#     400             raise ValueError(
# --> 401                 f"X has {n_features} features, but {self.__class__.__name__} "
#     402                 f"is expecting {self.n_features_in_} features as input."
#     403             )
#
# ValueError: X has 28 features, but ColumnTransformer is expecting 29 features as input.
