# %%
import pandas as pd
pd.set_option('display.max_columns', None)

train = pd.read_csv('../data/train_data.csv')
test = pd.read_csv('../data/test_data.csv')

# %%
# Vamos a definir los datos de entrenamiento
X = train.drop(['mineralType', 'id'], axis=1)
y = train['mineralType']

# %%
X['planetSection'] = X['planetSection'].astype('category')
X['geoZone'] = X['geoZone'].astype('category')
X['rockSize'] = X['rockSize'].astype('category')
X['cover'] = X['cover'].astype('category')
X['magmaConcentrationDistance'] = X['magmaConcentrationDistance'].astype('category')

# %%
from autosklearn.experimental.askl2 import AutoSklearn2Classifier
from autosklearn.classification import AutoSklearnClassifier
from autosklearn.metrics import accuracy

# Create sklearn pipeline for data preprocessing
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer, OneHotEncoder, OrdinalEncoder, StandardScaler, RobustScaler
from sklearn.feature_extraction import FeatureHasher
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer, IterativeImputer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import LinearSVC
from sklearn.neural_network import MLPClassifier
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, make_scorer, recall_score, precision_score
from sklearn.decomposition import PCA, NMF
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn import set_config
import numpy as np
import mlflow
import math
from joblib import Memory
from shutil import rmtree

mlflow.sklearn.autolog()
mlflow.set_experiment("autosklearn_preprocessor")

preprocessor = ColumnTransformer([
        # (name, transformer, columns)
        ("temperatureFirstHalfPlanetRotation", make_pipeline(IterativeImputer(missing_values=-999.0), FunctionTransformer(lambda f: (f - 32) / 1.8, feature_names_out="one-to-one"), RobustScaler()), ['temperatureFirstHalfPlanetRotation']), # convert from Fahrenheit to Celsius
        ("temperatureSecondHalfPlanetRotation", StandardScaler(), ['temperatureSecondHalfPlanetRotation']), # pass through the column unchanged
        ("waterStreamDistanceX", make_pipeline(FunctionTransformer(lambda f: f * 0.3048, feature_names_out="one-to-one"), StandardScaler()), ['waterStreamDistanceX']), # convert from feet to meters
        ("waterStreamDistanceY", StandardScaler(), ['waterStreamDistanceY']), # pass through the column unchanged
        ("planetSection", OneHotEncoder(handle_unknown = "ignore"), ['planetSection']), # one-hot encode the planetSection column
        ("cover", OneHotEncoder(handle_unknown='error', drop='first'), ['cover']), # one-hot encode the cover column and drop the first column (the one with the missing values == 0)
        ("climaticZone", OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1), ['climaticZone']), # ordinal encode the climaticZone column TODO: drop category 3? what to do? only one row has a 3
        ("geoZone", OneHotEncoder(handle_unknown = "ignore"), ['geoZone']), # one-hot encode the geoZone column TODO: drop category 5?
        ("rockSize", OneHotEncoder(handle_unknown='ignore', drop='first'), ['rockSize']), # one-hot encode the rockSize column and drop the first column (the one with the missing values == 0)
        ("magmaConcentrationDistance", OneHotEncoder(handle_unknown = "ignore"), ['magmaConcentrationDistance']), # one-hot encode the rockSize column and drop the first column (the one with the missing values == 0) TODO: use Ordinal Encoder?
        ("mineralDensity", make_pipeline(IterativeImputer(missing_values=-999.0), RobustScaler()), ['mineralDensity']), # pass through the column unchanged
        ("detectionDepth", StandardScaler(), ['detectionDepth']), # pass through the column unchanged TODO: convert km to m?
        ("longitude", StandardScaler(), ['longitude']), # pass through the column unchanged TODO: values > 360? do x - 360
    ],
    verbose_feature_names_out=False, remainder='passthrough'
)

def euclidean_distance(x, y):
    res = []
    for i in range(len(x)):
        res.append(math.sqrt(x[i]**2 + y[i]**2))
    return np.array(res)

class CreateVariables(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
        
    def fit(self, X, y = None):
        return self

    def transform(self, X, y = None):
        # waterSteamDistance
        waterStreamDistanceX = X[:,2]
        waterStreamDistanceY = X[:,3]
        waterStreamDistance = euclidean_distance(waterStreamDistanceX, waterStreamDistanceY)
        X = np.append(X, waterStreamDistance.reshape(-1, 1), axis=1)

        # temperature (both planet rotations)
        temperatureFirstHalfPlanetRotation = X[:,0]
        temperatureSecondHalfPlanetRotation = X[:,1]
        meanTemperature = (temperatureFirstHalfPlanetRotation + temperatureSecondHalfPlanetRotation)/2
        X = np.append(X, meanTemperature.reshape(-1, 1), axis=1)

        return X

pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('create_variables', CreateVariables()),
    # ('pca', PCA()),
    # ('model', AutoSklearn2Classifier(n_jobs=-1, metric=accuracy, time_left_for_this_task=60,
    #             # include={
    #             #     'data_preprocessor': ['NoPreprocessing']
    #             # }
    #          )
    # )
])

cls = AutoSklearn2Classifier(n_jobs=-1, metric=accuracy, time_left_for_this_task=300)
cls.fit(pipe.fit_transform(X), y)
# Out:
# 2022/04/28 19:41:04 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2022/04/28 19:41:04 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '5d93c32fde154c1eb2d253466cf2ddbb', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2022/04/28 19:41:04 WARNING mlflow.utils: Truncated the value of the key `steps`. Truncated value: `[('preprocessor', ColumnTransformer(remainder='passthrough',
#                   transformers=[('temperatureFirstHalfPlanetRotation',
#                                  Pipeline(steps=[('iterativeimputer',
#                                              ...`
# 2022/04/28 19:41:04 WARNING mlflow.utils: Truncated the value of the key `preprocessor`. Truncated value: `ColumnTransformer(remainder='passthrough',
#                   transformers=[('temperatureFirstHalfPlanetRotation',
#                                  Pipeline(steps=[('iterativeimputer',
#                                                   IterativeImpu...`
# 2022/04/28 19:41:05 WARNING mlflow.utils: Truncated the value of the key `preprocessor__transformers`. Truncated value: `[('temperatureFirstHalfPlanetRotation', Pipeline(steps=[('iterativeimputer', IterativeImputer(missing_values=-999.0)),
#                 ('functiontransformer',
#                  FunctionTransformer(feature_names_out='one-to-one',
#                    ...`
# 2022/04/28 19:41:05 WARNING mlflow.utils: Truncated the value of the key `preprocessor__temperatureFirstHalfPlanetRotation`. Truncated value: `Pipeline(steps=[('iterativeimputer', IterativeImputer(missing_values=-999.0)),
#                 ('functiontransformer',
#                  FunctionTransformer(feature_names_out='one-to-one',
#                                      func=<function <lambda...`
# 2022/04/28 19:41:05 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2022/04/28 19:41:05 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not specify a `predict` function, which is required in order to infer the signature
# /home/sergio/.pyenv/versions/3.7.13/envs/fase6/lib/python3.7/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 42861 instead
#   f"Port {expected} is already in use.\n"
# [WARNING] [2022-04-28 19:41:26,752:Client-AutoML(1):6d4e8dd2-c71a-11ec-a1f9-00155d6e34f2] Capping the per_run_time_limit to 149.0 to have time for a least 2 models in each process.
# AutoSklearn2Classifier(metric=accuracy, n_jobs=-1, per_run_time_limit=240,
#                        time_left_for_this_task=300)

# %%
cls.sprint_statistics()
# Out:
# 'auto-sklearn results:\n  Dataset name: 6d4e8dd2-c71a-11ec-a1f9-00155d6e34f2\n  Metric: accuracy\n  Best validation score: 0.758815\n  Number of target algorithm runs: 21\n  Number of successful target algorithm runs: 19\n  Number of crashed target algorithm runs: 0\n  Number of target algorithms that exceeded the time limit: 2\n  Number of target algorithms that exceeded the memory limit: 0\n'

# %%
cls.show_models()
# Out:
# {14: {'model_id': 14,
#   'rank': 1,
#   'cost': 0.2411853260438951,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7fadf52087d0>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7fadf539cfd0>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7fadf5175650>,
#   'sklearn_classifier': None},
#  2: {'model_id': 2,
#   'rank': 2,
#   'cost': 0.25346644481419855,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7fadf4b00ad0>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7fadf5156b50>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7fadf5156090>,
#   'sklearn_classifier': None},
#  17: {'model_id': 17,
#   'rank': 3,
#   'cost': 0.2808018382061643,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7fadf4e40290>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7fadf5107110>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7fadf5107a10>,
#   'sklearn_classifier': None},
#  9: {'model_id': 9,
#   'rank': 4,
#   'cost': 0.4823706520877902,
#   'ensemble_weight': 0.94,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7fadf4be2b10>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7fadf4982a90>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7fadf4982c10>,
#   'sklearn_classifier': None}}

# %%
cls.leaderboard()
# Out:
#           rank  ensemble_weight               type      cost    duration
# model_id
# 14           1             0.02        extra_trees  0.241185  149.167808
# 2            2             0.02        extra_trees  0.253466  149.144670
# 17           3             0.02  gradient_boosting  0.280802  137.062096
# 9            4             0.94                sgd  0.482371   32.833851

# %%
pd.DataFrame(cls.cv_results_).sort_values(by=['rank_test_scores'], ascending=True).head(10)
# Out:
#     mean_test_score  mean_fit_time  \
# 12         0.758815     149.167808
# 0          0.746534     149.144670
# 16         0.729340     137.190558
# 15         0.719198     137.062096
# 1          0.718485     149.066342
# 3          0.713018     149.092871
# 4          0.711196     149.069518
# 17         0.703510     134.124143
# 13         0.643531     137.057894
# 10         0.612788     121.032433
#
#                                                params  rank_test_scores  \
# 12  {'balancing:strategy': 'weighting', 'classifie...                 1
# 0   {'balancing:strategy': 'weighting', 'classifie...                 2
# 16  {'balancing:strategy': 'none', 'classifier:__c...                 3
# 15  {'balancing:strategy': 'weighting', 'classifie...                 4
# 1   {'balancing:strategy': 'weighting', 'classifie...                 5
# 3   {'balancing:strategy': 'weighting', 'classifie...                 6
# 4   {'balancing:strategy': 'weighting', 'classifie...                 7
# 17  {'balancing:strategy': 'weighting', 'classifie...                 8
# 13  {'balancing:strategy': 'weighting', 'classifie...                 9
# 10  {'balancing:strategy': 'none', 'classifier:__c...                10
#
#      status  budgets param_balancing:strategy param_classifier:__choice__  \
# 12  Success      0.0                weighting                 extra_trees
# 0   Success      0.0                weighting                 extra_trees
# 16  Success      0.0                     none               random_forest
# 15  Success      0.0                weighting           gradient_boosting
# 1   Success      0.0                weighting           gradient_boosting
# 3   Success      0.0                weighting           gradient_boosting
# 4   Success      0.0                weighting           gradient_boosting
# 17  Success      0.0                weighting           gradient_boosting
# 13  Success      0.0                weighting                 extra_trees
# 10  Success      0.0                     none           gradient_boosting
#
#    param_data_preprocessor:__choice__ param_feature_preprocessor:__choice__  \
# 12                       feature_type                      no_preprocessing
# 0                        feature_type                      no_preprocessing
# 16                       feature_type                      no_preprocessing
# 15                       feature_type                      no_preprocessing
# 1                        feature_type                      no_preprocessing
# 3                        feature_type                      no_preprocessing
# 4                        feature_type                      no_preprocessing
# 17                       feature_type                      no_preprocessing
# 13                       feature_type                      no_preprocessing
# 10                       feature_type                      no_preprocessing
#
#    param_classifier:extra_trees:bootstrap  \
# 12                                  False
# 0                                   False
# 16                                    NaN
# 15                                    NaN
# 1                                     NaN
# 3                                     NaN
# 4                                     NaN
# 17                                    NaN
# 13                                   True
# 10                                    NaN
#
#    param_classifier:extra_trees:criterion  \
# 12                                entropy
# 0                                 entropy
# 16                                    NaN
# 15                                    NaN
# 1                                     NaN
# 3                                     NaN
# 4                                     NaN
# 17                                    NaN
# 13                                entropy
# 10                                    NaN
#
#    param_classifier:extra_trees:max_depth  \
# 12                                   None
# 0                                    None
# 16                                    NaN
# 15                                    NaN
# 1                                     NaN
# 3                                     NaN
# 4                                     NaN
# 17                                    NaN
# 13                                   None
# 10                                    NaN
#
#     param_classifier:extra_trees:max_features  \
# 12                                   0.958941
# 0                                    0.956590
# 16                                        NaN
# 15                                        NaN
# 1                                         NaN
# 3                                         NaN
# 4                                         NaN
# 17                                        NaN
# 13                                   0.278607
# 10                                        NaN
#
#    param_classifier:extra_trees:max_leaf_nodes  \
# 12                                        None
# 0                                         None
# 16                                         NaN
# 15                                         NaN
# 1                                          NaN
# 3                                          NaN
# 4                                          NaN
# 17                                         NaN
# 13                                        None
# 10                                         NaN
#
#     param_classifier:extra_trees:min_impurity_decrease  \
# 12                                                0.0
# 0                                                 0.0
# 16                                                NaN
# 15                                                NaN
# 1                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 17                                                NaN
# 13                                                0.0
# 10                                                NaN
#
#     param_classifier:extra_trees:min_samples_leaf  \
# 12                                            1.0
# 0                                             4.0
# 16                                            NaN
# 15                                            NaN
# 1                                             NaN
# 3                                             NaN
# 4                                             NaN
# 17                                            NaN
# 13                                           16.0
# 10                                            NaN
#
#     param_classifier:extra_trees:min_samples_split  \
# 12                                             5.0
# 0                                             15.0
# 16                                             NaN
# 15                                             NaN
# 1                                              NaN
# 3                                              NaN
# 4                                              NaN
# 17                                             NaN
# 13                                            16.0
# 10                                             NaN
#
#     param_classifier:extra_trees:min_weight_fraction_leaf  \
# 12                                                0.0
# 0                                                 0.0
# 16                                                NaN
# 15                                                NaN
# 1                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 17                                                NaN
# 13                                                0.0
# 10                                                NaN
#
#    param_classifier:gradient_boosting:early_stop  \
# 12                                           NaN
# 0                                            NaN
# 16                                           NaN
# 15                                           off
# 1                                          train
# 3                                          valid
# 4                                          valid
# 17                                         valid
# 13                                           NaN
# 10                                         train
#
#     param_classifier:gradient_boosting:l2_regularization  \
# 12                                                NaN
# 0                                                 NaN
# 16                                                NaN
# 15                                       6.413435e-02
# 1                                        8.789671e-10
# 3                                        1.021041e-09
# 4                                        7.351154e-07
# 17                                       1.019700e-10
# 13                                                NaN
# 10                                       1.621317e-04
#
#     param_classifier:gradient_boosting:learning_rate  \
# 12                                               NaN
# 0                                                NaN
# 16                                               NaN
# 15                                          0.196618
# 1                                           0.195957
# 3                                           0.192989
# 4                                           0.070436
# 17                                          0.083654
# 13                                               NaN
# 10                                          0.796280
#
#    param_classifier:gradient_boosting:loss  \
# 12                                     NaN
# 0                                      NaN
# 16                                     NaN
# 15                                    auto
# 1                                     auto
# 3                                     auto
# 4                                     auto
# 17                                    auto
# 13                                     NaN
# 10                                    auto
#
#     param_classifier:gradient_boosting:max_bins  \
# 12                                          NaN
# 0                                           NaN
# 16                                          NaN
# 15                                        255.0
# 1                                         255.0
# 3                                         255.0
# 4                                         255.0
# 17                                        255.0
# 13                                          NaN
# 10                                        255.0
#
#    param_classifier:gradient_boosting:max_depth  \
# 12                                          NaN
# 0                                           NaN
# 16                                          NaN
# 15                                         None
# 1                                          None
# 3                                          None
# 4                                          None
# 17                                         None
# 13                                          NaN
# 10                                         None
#
#     param_classifier:gradient_boosting:max_leaf_nodes  \
# 12                                                NaN
# 0                                                 NaN
# 16                                                NaN
# 15                                              103.0
# 1                                                10.0
# 3                                                10.0
# 4                                               698.0
# 17                                               10.0
# 13                                                NaN
# 10                                              183.0
#
#     param_classifier:gradient_boosting:min_samples_leaf  \
# 12                                                NaN
# 0                                                 NaN
# 16                                                NaN
# 15                                                1.0
# 1                                                 2.0
# 3                                                20.0
# 4                                                 7.0
# 17                                               41.0
# 13                                                NaN
# 10                                               21.0
#
#    param_classifier:gradient_boosting:scoring  \
# 12                                        NaN
# 0                                         NaN
# 16                                        NaN
# 15                                       loss
# 1                                        loss
# 3                                        loss
# 4                                        loss
# 17                                       loss
# 13                                        NaN
# 10                                       loss
#
#     param_classifier:gradient_boosting:tol param_classifier:mlp:activation  \
# 12                                     NaN                             NaN
# 0                                      NaN                             NaN
# 16                                     NaN                             NaN
# 15                            1.000000e-07                             NaN
# 1                             1.000000e-07                             NaN
# 3                             1.000000e-07                             NaN
# 4                             1.000000e-07                             NaN
# 17                            1.000000e-07                             NaN
# 13                                     NaN                             NaN
# 10                            1.000000e-07                             NaN
#
#     param_classifier:mlp:alpha param_classifier:mlp:batch_size  \
# 12                         NaN                             NaN
# 0                          NaN                             NaN
# 16                         NaN                             NaN
# 15                         NaN                             NaN
# 1                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          NaN                             NaN
# 17                         NaN                             NaN
# 13                         NaN                             NaN
# 10                         NaN                             NaN
#
#     param_classifier:mlp:beta_1  param_classifier:mlp:beta_2  \
# 12                          NaN                          NaN
# 0                           NaN                          NaN
# 16                          NaN                          NaN
# 15                          NaN                          NaN
# 1                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# 17                          NaN                          NaN
# 13                          NaN                          NaN
# 10                          NaN                          NaN
#
#    param_classifier:mlp:early_stopping  param_classifier:mlp:epsilon  \
# 12                                 NaN                           NaN
# 0                                  NaN                           NaN
# 16                                 NaN                           NaN
# 15                                 NaN                           NaN
# 1                                  NaN                           NaN
# 3                                  NaN                           NaN
# 4                                  NaN                           NaN
# 17                                 NaN                           NaN
# 13                                 NaN                           NaN
# 10                                 NaN                           NaN
#
#     param_classifier:mlp:hidden_layer_depth  \
# 12                                      NaN
# 0                                       NaN
# 16                                      NaN
# 15                                      NaN
# 1                                       NaN
# 3                                       NaN
# 4                                       NaN
# 17                                      NaN
# 13                                      NaN
# 10                                      NaN
#
#     param_classifier:mlp:learning_rate_init  \
# 12                                      NaN
# 0                                       NaN
# 16                                      NaN
# 15                                      NaN
# 1                                       NaN
# 3                                       NaN
# 4                                       NaN
# 17                                      NaN
# 13                                      NaN
# 10                                      NaN
#
#     param_classifier:mlp:n_iter_no_change  \
# 12                                    NaN
# 0                                     NaN
# 16                                    NaN
# 15                                    NaN
# 1                                     NaN
# 3                                     NaN
# 4                                     NaN
# 17                                    NaN
# 13                                    NaN
# 10                                    NaN
#
#     param_classifier:mlp:num_nodes_per_layer param_classifier:mlp:shuffle  \
# 12                                       NaN                          NaN
# 0                                        NaN                          NaN
# 16                                       NaN                          NaN
# 15                                       NaN                          NaN
# 1                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# 17                                       NaN                          NaN
# 13                                       NaN                          NaN
# 10                                       NaN                          NaN
#
#    param_classifier:mlp:solver  param_classifier:mlp:tol  \
# 12                         NaN                       NaN
# 0                          NaN                       NaN
# 16                         NaN                       NaN
# 15                         NaN                       NaN
# 1                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# 17                         NaN                       NaN
# 13                         NaN                       NaN
# 10                         NaN                       NaN
#
#     param_classifier:passive_aggressive:C  \
# 12                                    NaN
# 0                                     NaN
# 16                                    NaN
# 15                                    NaN
# 1                                     NaN
# 3                                     NaN
# 4                                     NaN
# 17                                    NaN
# 13                                    NaN
# 10                                    NaN
#
#    param_classifier:passive_aggressive:average  \
# 12                                         NaN
# 0                                          NaN
# 16                                         NaN
# 15                                         NaN
# 1                                          NaN
# 3                                          NaN
# 4                                          NaN
# 17                                         NaN
# 13                                         NaN
# 10                                         NaN
#
#    param_classifier:passive_aggressive:fit_intercept  \
# 12                                               NaN
# 0                                                NaN
# 16                                               NaN
# 15                                               NaN
# 1                                                NaN
# 3                                                NaN
# 4                                                NaN
# 17                                               NaN
# 13                                               NaN
# 10                                               NaN
#
#    param_classifier:passive_aggressive:loss  \
# 12                                      NaN
# 0                                       NaN
# 16                                      NaN
# 15                                      NaN
# 1                                       NaN
# 3                                       NaN
# 4                                       NaN
# 17                                      NaN
# 13                                      NaN
# 10                                      NaN
#
#     param_classifier:passive_aggressive:tol  \
# 12                                      NaN
# 0                                       NaN
# 16                                      NaN
# 15                                      NaN
# 1                                       NaN
# 3                                       NaN
# 4                                       NaN
# 17                                      NaN
# 13                                      NaN
# 10                                      NaN
#
#    param_classifier:random_forest:bootstrap  \
# 12                                      NaN
# 0                                       NaN
# 16                                    False
# 15                                      NaN
# 1                                       NaN
# 3                                       NaN
# 4                                       NaN
# 17                                      NaN
# 13                                      NaN
# 10                                      NaN
#
#    param_classifier:random_forest:criterion  \
# 12                                      NaN
# 0                                       NaN
# 16                                     gini
# 15                                      NaN
# 1                                       NaN
# 3                                       NaN
# 4                                       NaN
# 17                                      NaN
# 13                                      NaN
# 10                                      NaN
#
#    param_classifier:random_forest:max_depth  \
# 12                                      NaN
# 0                                       NaN
# 16                                     None
# 15                                      NaN
# 1                                       NaN
# 3                                       NaN
# 4                                       NaN
# 17                                      NaN
# 13                                      NaN
# 10                                      NaN
#
#     param_classifier:random_forest:max_features  \
# 12                                          NaN
# 0                                           NaN
# 16                                     0.872766
# 15                                          NaN
# 1                                           NaN
# 3                                           NaN
# 4                                           NaN
# 17                                          NaN
# 13                                          NaN
# 10                                          NaN
#
#    param_classifier:random_forest:max_leaf_nodes  \
# 12                                           NaN
# 0                                            NaN
# 16                                          None
# 15                                           NaN
# 1                                            NaN
# 3                                            NaN
# 4                                            NaN
# 17                                           NaN
# 13                                           NaN
# 10                                           NaN
#
#     param_classifier:random_forest:min_impurity_decrease  \
# 12                                                NaN
# 0                                                 NaN
# 16                                                0.0
# 15                                                NaN
# 1                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 17                                                NaN
# 13                                                NaN
# 10                                                NaN
#
#     param_classifier:random_forest:min_samples_leaf  \
# 12                                              NaN
# 0                                               NaN
# 16                                             11.0
# 15                                              NaN
# 1                                               NaN
# 3                                               NaN
# 4                                               NaN
# 17                                              NaN
# 13                                              NaN
# 10                                              NaN
#
#     param_classifier:random_forest:min_samples_split  \
# 12                                               NaN
# 0                                                NaN
# 16                                              15.0
# 15                                               NaN
# 1                                                NaN
# 3                                                NaN
# 4                                                NaN
# 17                                               NaN
# 13                                               NaN
# 10                                               NaN
#
#     param_classifier:random_forest:min_weight_fraction_leaf  \
# 12                                                NaN
# 0                                                 NaN
# 16                                                0.0
# 15                                                NaN
# 1                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 17                                                NaN
# 13                                                NaN
# 10                                                NaN
#
#     param_classifier:sgd:alpha param_classifier:sgd:average  \
# 12                         NaN                          NaN
# 0                          NaN                          NaN
# 16                         NaN                          NaN
# 15                         NaN                          NaN
# 1                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# 17                         NaN                          NaN
# 13                         NaN                          NaN
# 10                         NaN                          NaN
#
#    param_classifier:sgd:fit_intercept param_classifier:sgd:learning_rate  \
# 12                                NaN                                NaN
# 0                                 NaN                                NaN
# 16                                NaN                                NaN
# 15                                NaN                                NaN
# 1                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
# 17                                NaN                                NaN
# 13                                NaN                                NaN
# 10                                NaN                                NaN
#
#    param_classifier:sgd:loss param_classifier:sgd:penalty  \
# 12                       NaN                          NaN
# 0                        NaN                          NaN
# 16                       NaN                          NaN
# 15                       NaN                          NaN
# 1                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        NaN                          NaN
# 17                       NaN                          NaN
# 13                       NaN                          NaN
# 10                       NaN                          NaN
#
#     param_classifier:sgd:tol  \
# 12                       NaN
# 0                        NaN
# 16                       NaN
# 15                       NaN
# 1                        NaN
# 3                        NaN
# 4                        NaN
# 17                       NaN
# 13                       NaN
# 10                       NaN
#
#    param_data_preprocessor:feature_type:categorical_transformer:categorical_encoding:__choice__  \
# 12                                   one_hot_encoding
# 0                                         no_encoding
# 16                                   one_hot_encoding
# 15                                        no_encoding
# 1                                         no_encoding
# 3                                    one_hot_encoding
# 4                                    one_hot_encoding
# 17                                   one_hot_encoding
# 13                                        no_encoding
# 10                                        no_encoding
#
#    param_data_preprocessor:feature_type:categorical_transformer:category_coalescence:__choice__  \
# 12                                 minority_coalescer
# 0                                  minority_coalescer
# 16                                 minority_coalescer
# 15                                 minority_coalescer
# 1                                  minority_coalescer
# 3                                      no_coalescense
# 4                                      no_coalescense
# 17                                     no_coalescense
# 13                                     no_coalescense
# 10                                     no_coalescense
#
#    param_data_preprocessor:feature_type:numerical_transformer:imputation:strategy  \
# 12                                               mean
# 0                                       most_frequent
# 16                                             median
# 15                                             median
# 1                                              median
# 3                                              median
# 4                                              median
# 17                                      most_frequent
# 13                                               mean
# 10                                             median
#
#    param_data_preprocessor:feature_type:numerical_transformer:rescaling:__choice__  \
# 12                                             minmax
# 0                                       robust_scaler
# 16                                      robust_scaler
# 15                                  power_transformer
# 1                                                none
# 3                                quantile_transformer
# 4                                           normalize
# 17                                             minmax
# 13                                      robust_scaler
# 10                               quantile_transformer
#
#     param_classifier:gradient_boosting:n_iter_no_change  \
# 12                                                NaN
# 0                                                 NaN
# 16                                                NaN
# 15                                                NaN
# 1                                                13.0
# 3                                                 6.0
# 4                                                 1.0
# 17                                                3.0
# 13                                                NaN
# 10                                                3.0
#
#     param_classifier:gradient_boosting:validation_fraction  \
# 12                                                NaN
# 0                                                 NaN
# 16                                                NaN
# 15                                                NaN
# 1                                                 NaN
# 3                                            0.115496
# 4                                            0.162028
# 17                                           0.140534
# 13                                                NaN
# 10                                                NaN
#
#     param_classifier:mlp:validation_fraction  param_classifier:sgd:epsilon  \
# 12                                       NaN                           NaN
# 0                                        NaN                           NaN
# 16                                       NaN                           NaN
# 15                                       NaN                           NaN
# 1                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# 17                                       NaN                           NaN
# 13                                       NaN                           NaN
# 10                                       NaN                           NaN
#
#     param_classifier:sgd:eta0  param_classifier:sgd:l1_ratio  \
# 12                        NaN                            NaN
# 0                         NaN                            NaN
# 16                        NaN                            NaN
# 15                        NaN                            NaN
# 1                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
# 17                        NaN                            NaN
# 13                        NaN                            NaN
# 10                        NaN                            NaN
#
#     param_classifier:sgd:power_t  \
# 12                           NaN
# 0                            NaN
# 16                           NaN
# 15                           NaN
# 1                            NaN
# 3                            NaN
# 4                            NaN
# 17                           NaN
# 13                           NaN
# 10                           NaN
#
#     param_data_preprocessor:feature_type:categorical_transformer:category_coalescence:minority_coalescer:minimum_fraction  \
# 12                                           0.003691
# 0                                            0.118408
# 16                                           0.027147
# 15                                           0.009713
# 1                                            0.001314
# 3                                                 NaN
# 4                                                 NaN
# 17                                                NaN
# 13                                                NaN
# 10                                                NaN
#
#     param_data_preprocessor:feature_type:numerical_transformer:rescaling:quantile_transformer:n_quantiles  \
# 12                                                NaN
# 0                                                 NaN
# 16                                                NaN
# 15                                                NaN
# 1                                                 NaN
# 3                                               452.0
# 4                                                 NaN
# 17                                                NaN
# 13                                                NaN
# 10                                               82.0
#
#    param_data_preprocessor:feature_type:numerical_transformer:rescaling:quantile_transformer:output_distribution  \
# 12                                                NaN
# 0                                                 NaN
# 16                                                NaN
# 15                                                NaN
# 1                                                 NaN
# 3                                             uniform
# 4                                                 NaN
# 17                                                NaN
# 13                                                NaN
# 10                                             normal
#
#     param_data_preprocessor:feature_type:numerical_transformer:rescaling:robust_scaler:q_max  \
# 12                                                NaN
# 0                                            0.766873
# 16                                           0.730022
# 15                                                NaN
# 1                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 17                                                NaN
# 13                                           0.856360
# 10                                                NaN
#
#     param_data_preprocessor:feature_type:numerical_transformer:rescaling:robust_scaler:q_min
# 12                                                NaN
# 0                                            0.286333
# 16                                           0.239920
# 15                                                NaN
# 1                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 17                                                NaN
# 13                                           0.041173
# 10                                                NaN
