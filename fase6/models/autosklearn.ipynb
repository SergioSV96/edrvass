# %%
import pandas as pd
pd.set_option('display.max_columns', None)

train = pd.read_csv('../data/train_data.csv')
test = pd.read_csv('../data/test_data.csv')

# %%
# Vamos a definir los datos de entrenamiento
X = train.drop(['mineralType', 'id'], axis=1)
y = train['mineralType']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12621 entries, 0 to 12620
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   climaticZone                         12621 non-null  int64
#  1   planetSection                        12621 non-null  object
#  2   temperatureSecondHalfPlanetRotation  12621 non-null  float64
#  3   temperatureFirstHalfPlanetRotation   12621 non-null  float64
#  4   mineralDensity                       12621 non-null  float64
#  5   geoZone                              12621 non-null  int64
#  6   longitude                            12621 non-null  float64
#  7   rockSize                             12621 non-null  int64
#  8   waterStreamDistanceY                 12621 non-null  float64
#  9   cover                                12621 non-null  int64
#  10  magmaConcentrationDistance           12621 non-null  object
#  11  waterStreamDistanceX                 12621 non-null  float64
#  12  detectionDepth                       12621 non-null  float64
# dtypes: float64(7), int64(4), object(2)
# memory usage: 1.3+ MB

# %%
X['planetSection'] = X['planetSection'].astype('category')
X['geoZone'] = X['geoZone'].astype('category')
X['rockSize'] = X['rockSize'].astype('category')
X['cover'] = X['cover'].astype('category')
X['magmaConcentrationDistance'] = X['magmaConcentrationDistance'].astype('category')

# %%
import autosklearn.classification
from autosklearn.metrics import accuracy

cls = autosklearn.classification.AutoSklearnClassifier(n_jobs=-1, metric=accuracy)
cls.fit(X, y)
# Out:
# /home/sergio/.pyenv/versions/3.7.13/lib/python3.7/contextlib.py:119: UserWarning: Creating scratch directories is taking a surprisingly long time. This is often due to running workers on a network file system. Consider specifying a local-directory to point workers to write scratch data to a local disk.
#   next(self.gen)
# [WARNING] [2022-04-26 09:43:28,116:Client-AutoML(1):8c13f582-c534-11ec-a5ee-00155d059331] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# AutoSklearnClassifier(metric=accuracy, n_jobs=-1, per_run_time_limit=2880)

# %%
cls.sprint_statistics()
# Out:
# 'auto-sklearn results:\n  Dataset name: 8c13f582-c534-11ec-a5ee-00155d059331\n  Metric: accuracy\n  Best validation score: 0.756062\n  Number of target algorithm runs: 183\n  Number of successful target algorithm runs: 173\n  Number of crashed target algorithm runs: 3\n  Number of target algorithms that exceeded the time limit: 6\n  Number of target algorithms that exceeded the memory limit: 1\n'

# %%
import matplotlib.pyplot as plt

cls.performance_over_time_.plot(
        x='Timestamp',
        kind='line',
        legend=True,
        title='Auto-sklearn accuracy over time',
        grid=True,
    )
plt.show()

# %%
cls.show_models()
# Out:
# {128: {'model_id': 128,
#   'rank': 1,
#   'cost': 0.243937575030012,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f710ca6b150>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f7174e1f450>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f7174e52dd0>,
#   'sklearn_classifier': RandomForestClassifier(bootstrap=False, max_features=26, min_samples_split=4,
#                          n_estimators=512, n_jobs=1, random_state=1,
#                          warm_start=True)},
#  136: {'model_id': 136,
#   'rank': 2,
#   'cost': 0.24585834333733492,
#   'ensemble_weight': 0.1,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70d5e4cb10>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70e37b1ed0>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70ee4334d0>,
#   'sklearn_classifier': RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=6,
#                          min_samples_split=3, n_estimators=512, n_jobs=1,
#                          random_state=1, warm_start=True)},
#  132: {'model_id': 132,
#   'rank': 3,
#   'cost': 0.24609843937575027,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70ef7a36d0>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70ddd6b910>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70d095dd10>,
#   'sklearn_classifier': RandomForestClassifier(max_features=6, n_estimators=512, n_jobs=1,
#                          random_state=1, warm_start=True)},
#  143: {'model_id': 143,
#   'rank': 4,
#   'cost': 0.24633853541416562,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70f0edd5d0>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70d984e1d0>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70ee18e990>,
#   'sklearn_classifier': RandomForestClassifier(bootstrap=False, max_features=6, min_samples_split=4,
#                          n_estimators=512, n_jobs=1, random_state=1,
#                          warm_start=True)},
#  96: {'model_id': 96,
#   'rank': 5,
#   'cost': 0.24777911164465782,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70d32e2d90>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70d1503410>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70d1503c50>,
#   'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=7, min_samples_split=5,
#                          n_estimators=512, n_jobs=1, random_state=1,
#                          warm_start=True)},
#  141: {'model_id': 141,
#   'rank': 6,
#   'cost': 0.24777911164465782,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70d5067c50>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70ed768410>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70da31bf50>,
#   'sklearn_classifier': RandomForestClassifier(bootstrap=False, max_features=9, min_samples_split=3,
#                          n_estimators=512, n_jobs=1, random_state=1,
#                          warm_start=True)},
#  167: {'model_id': 167,
#   'rank': 7,
#   'cost': 0.24825930372148863,
#   'ensemble_weight': 0.06,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70e128a050>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70d0493bd0>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70d1b59c90>,
#   'sklearn_classifier': RandomForestClassifier(bootstrap=False, max_features=5, min_samples_split=4,
#                          n_estimators=512, n_jobs=1, random_state=1,
#                          warm_start=True)},
#  124: {'model_id': 124,
#   'rank': 8,
#   'cost': 0.24897959183673468,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70d8eb9a90>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70cfef3250>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70cfef3210>,
#   'sklearn_classifier': RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=5,
#                          min_samples_split=8, n_estimators=512, n_jobs=1,
#                          random_state=1, warm_start=True)},
#  131: {'model_id': 131,
#   'rank': 9,
#   'cost': 0.24921968787515003,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70d0d913d0>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70cf67ea50>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70f0600850>,
#   'sklearn_classifier': RandomForestClassifier(bootstrap=False, max_features=11, min_samples_split=5,
#                          n_estimators=512, n_jobs=1, random_state=1,
#                          warm_start=True)},
#  169: {'model_id': 169,
#   'rank': 10,
#   'cost': 0.24945978391356538,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70cf67b690>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70d1cf1710>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70d1cf1250>,
#   'sklearn_classifier': RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=7,
#                          min_samples_split=4, n_estimators=512, n_jobs=1,
#                          random_state=1, warm_start=True)},
#  2: {'model_id': 2,
#   'rank': 11,
#   'cost': 0.24969987995198084,
#   'ensemble_weight': 0.06,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70cf4597d0>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70d7c4b710>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70d120a710>,
#   'sklearn_classifier': RandomForestClassifier(max_features=5, n_estimators=512, n_jobs=1,
#                          random_state=1, warm_start=True)},
#  135: {'model_id': 135,
#   'rank': 12,
#   'cost': 0.2499399759903962,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70cf2b5390>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70cf09f810>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70cf09f8d0>,
#   'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=4, n_estimators=512,
#                          n_jobs=1, random_state=1, warm_start=True)},
#  146: {'model_id': 146,
#   'rank': 13,
#   'cost': 0.2499399759903962,
#   'ensemble_weight': 0.04,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70cf09a8d0>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70ceef2050>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70ceef2210>,
#   'sklearn_classifier': RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=8,
#                          min_samples_leaf=3, min_samples_split=4,
#                          n_estimators=512, n_jobs=1, random_state=1,
#                          warm_start=True)},
#  173: {'model_id': 173,
#   'rank': 14,
#   'cost': 0.25018007202881154,
#   'ensemble_weight': 0.04,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70ceef4050>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70cecd4190>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70cecd47d0>,
#   'sklearn_classifier': RandomForestClassifier(bootstrap=False, max_features=8, min_samples_split=4,
#                          n_estimators=512, n_jobs=1, random_state=1,
#                          warm_start=True)},
#  119: {'model_id': 119,
#   'rank': 15,
#   'cost': 0.2504201680672269,
#   'ensemble_weight': 0.06,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70cf39bc50>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70d0391510>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70cf4cb810>,
#   'sklearn_classifier': RandomForestClassifier(max_features=5, min_samples_split=3, n_estimators=512,
#                          n_jobs=1, random_state=1, warm_start=True)},
#  149: {'model_id': 149,
#   'rank': 16,
#   'cost': 0.25066026410564224,
#   'ensemble_weight': 0.04,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70ceb37990>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70ce916a10>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70ce916050>,
#   'sklearn_classifier': RandomForestClassifier(max_features=7, min_samples_split=3, n_estimators=512,
#                          n_jobs=1, random_state=1, warm_start=True)},
#  120: {'model_id': 120,
#   'rank': 17,
#   'cost': 0.2523409363745498,
#   'ensemble_weight': 0.04,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70ce94b510>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70ce76e950>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70ce76ee10>,
#   'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=22, n_estimators=512,
#                          n_jobs=1, random_state=1, warm_start=True)},
#  104: {'model_id': 104,
#   'rank': 18,
#   'cost': 0.2528211284513806,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70ce1928d0>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70ced4e490>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70ce935a10>,
#   'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=6,
#                          min_samples_split=12, n_estimators=512, n_jobs=1,
#                          random_state=1, warm_start=True)},
#  113: {'model_id': 113,
#   'rank': 19,
#   'cost': 0.2533013205282113,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70ce3a4450>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70cf1079d0>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70cf1075d0>,
#   'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=5,
#                          min_samples_split=14, n_estimators=512, n_jobs=1,
#                          random_state=1, warm_start=True)},
#  171: {'model_id': 171,
#   'rank': 20,
#   'cost': 0.2542617046818727,
#   'ensemble_weight': 0.06,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70ce3a86d0>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70ce20b2d0>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70ce20b850>,
#   'sklearn_classifier': RandomForestClassifier(bootstrap=False, max_features=7, min_samples_leaf=2,
#                          min_samples_split=18, n_estimators=512, n_jobs=1,
#                          random_state=1, warm_start=True)},
#  117: {'model_id': 117,
#   'rank': 21,
#   'cost': 0.2547418967587035,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70ce205850>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70cdff5f90>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70ced48490>,
#   'sklearn_classifier': RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=11,
#                          min_samples_split=16, n_estimators=512, n_jobs=1,
#                          random_state=1, warm_start=True)},
#  139: {'model_id': 139,
#   'rank': 22,
#   'cost': 0.25546218487394956,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70cdff04d0>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70ce792a10>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70ce792c50>,
#   'sklearn_classifier': RandomForestClassifier(max_features=5, min_samples_leaf=2, min_samples_split=6,
#                          n_estimators=512, n_jobs=1, random_state=1,
#                          warm_start=True)},
#  101: {'model_id': 101,
#   'rank': 23,
#   'cost': 0.25642256902761107,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70cde4cf10>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70cdc2e110>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70cdc2e750>,
#   'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=20,
#                          min_samples_split=14, n_estimators=512, n_jobs=1,
#                          random_state=1, warm_start=True)},
#  175: {'model_id': 175,
#   'rank': 24,
#   'cost': 0.2607442977190876,
#   'ensemble_weight': 0.14,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70cdf2cb10>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70cda8be50>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70ce757ed0>,
#   'sklearn_classifier': RandomForestClassifier(bootstrap=False, max_features=5, min_samples_split=5,
#                          n_estimators=512, n_jobs=1, random_state=1,
#                          warm_start=True)},
#  95: {'model_id': 95,
#   'rank': 25,
#   'cost': 0.2621848739495798,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70cde48a50>,
#   'balancing': Balancing(random_state=1, strategy='weighting'),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70cd866e10>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70cd866950>,
#   'sklearn_classifier': ExtraTreesClassifier(bootstrap=True, criterion='entropy', max_features=129,
#                        min_samples_leaf=6, min_samples_split=5, n_estimators=512,
#                        n_jobs=1, random_state=1, warm_start=True)},
#  134: {'model_id': 134,
#   'rank': 26,
#   'cost': 0.26890756302521013,
#   'ensemble_weight': 0.02,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70ede56710>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70cd654d10>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70cdfdb390>,
#   'sklearn_classifier': RandomForestClassifier(max_features=7, min_samples_split=4, n_estimators=512,
#                          n_jobs=1, random_state=1, warm_start=True)},
#  68: {'model_id': 68,
#   'rank': 27,
#   'cost': 0.273469387755102,
#   'ensemble_weight': 0.04,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x7f70cd651210>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x7f70cd8710d0>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x7f70ce3a8310>,
#   'sklearn_classifier': RandomForestClassifier(bootstrap=False, max_features=5, min_samples_leaf=15,
#                          n_estimators=512, n_jobs=1, random_state=1,
#                          warm_start=True)}}

# %%
cls.leaderboard()
# Out:
#           rank  ensemble_weight           type      cost    duration
# model_id
# 128          1             0.02  random_forest  0.243938  101.846408
# 136          2             0.10  random_forest  0.245858   43.341316
# 132          3             0.02  random_forest  0.246098   21.608883
# 143          4             0.02  random_forest  0.246339   37.410600
# 96           5             0.02  random_forest  0.247779   75.662097
# 141          6             0.02  random_forest  0.247779   46.524030
# 167          7             0.06  random_forest  0.248259   31.879905
# 124          8             0.02  random_forest  0.248980   54.822742
# 131          9             0.02  random_forest  0.249220   49.572663
# 169         10             0.02  random_forest  0.249460   56.335567
# 2           11             0.06  random_forest  0.249700   22.887760
# 135         12             0.02  random_forest  0.249940   33.688902
# 146         13             0.04  random_forest  0.249940   80.546170
# 173         14             0.04  random_forest  0.250180   40.589846
# 119         15             0.06  random_forest  0.250420   23.855862
# 149         16             0.04  random_forest  0.250660   38.632639
# 120         17             0.04  random_forest  0.252341  332.475095
# 104         18             0.02  random_forest  0.252821   34.710483
# 113         19             0.02  random_forest  0.253301   27.745555
# 171         20             0.06  random_forest  0.254262   33.481847
# 117         21             0.02  random_forest  0.254742  222.350771
# 139         22             0.02  random_forest  0.255462   26.611710
# 101         23             0.02  random_forest  0.256423  206.548065
# 175         24             0.14  random_forest  0.260744   82.139575
# 95          25             0.02    extra_trees  0.262185  145.804019
# 134         26             0.02  random_forest  0.268908  568.930289
# 68          27             0.04  random_forest  0.273469  128.782891

# %%
# import pickle

# # save model
# with open('../models/autosklearn.pkl', 'wb') as f:
#     pickle.dump(cls, f)

# %%
# import pickle

# # load model and calculate accuracy
# with open('../models/autosklearn.pkl', 'rb') as f:
#     cls = pickle.load(f)
