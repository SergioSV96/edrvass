# %%
from IPython.display import Markdown, display
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

train = pd.read_csv('data/train_data.csv')
test = pd.read_csv('data/test_data.csv')

# Pairgrid for train data for climaticZone
hue = 'climaticZone'
vars_per_line = 5
all_vars = list(train.columns.symmetric_difference([hue]))

for var in all_vars:
    rest_vars = list(all_vars)
    rest_vars.remove(var)
    display(Markdown(f"## {var}"))
    while rest_vars:
        line_vars = rest_vars[:vars_per_line]
        del rest_vars[:vars_per_line]
        line_var_names = ", ".join(line_vars)
        display(Markdown(f"### {var} vs {line_var_names}"))
        sns.pairplot(train, x_vars=line_vars, y_vars=[var], hue=hue, palette='bright', )
        plt.show()
        plt.close()
# Out:
# ## cover
# ### cover vs detectionDepth, geoZone, id, longitude, magmaConcentrationDistance
# ### cover vs mineralDensity, mineralType, planetSection, rockSize, temperatureFirstHalfPlanetRotation
# ### cover vs temperatureSecondHalfPlanetRotation, waterStreamDistanceX, waterStreamDistanceY
# ## detectionDepth
# ### detectionDepth vs cover, geoZone, id, longitude, magmaConcentrationDistance
# ### detectionDepth vs mineralDensity, mineralType, planetSection, rockSize, temperatureFirstHalfPlanetRotation
# ### detectionDepth vs temperatureSecondHalfPlanetRotation, waterStreamDistanceX, waterStreamDistanceY
# ## geoZone
# ### geoZone vs cover, detectionDepth, id, longitude, magmaConcentrationDistance
# ### geoZone vs mineralDensity, mineralType, planetSection, rockSize, temperatureFirstHalfPlanetRotation
# ### geoZone vs temperatureSecondHalfPlanetRotation, waterStreamDistanceX, waterStreamDistanceY
# ## id
# ### id vs cover, detectionDepth, geoZone, longitude, magmaConcentrationDistance
# ### id vs mineralDensity, mineralType, planetSection, rockSize, temperatureFirstHalfPlanetRotation
# ### id vs temperatureSecondHalfPlanetRotation, waterStreamDistanceX, waterStreamDistanceY
# ## longitude
# ### longitude vs cover, detectionDepth, geoZone, id, magmaConcentrationDistance
# ### longitude vs mineralDensity, mineralType, planetSection, rockSize, temperatureFirstHalfPlanetRotation
# ### longitude vs temperatureSecondHalfPlanetRotation, waterStreamDistanceX, waterStreamDistanceY
# ## magmaConcentrationDistance
# ### magmaConcentrationDistance vs cover, detectionDepth, geoZone, id, longitude
# ### magmaConcentrationDistance vs mineralDensity, mineralType, planetSection, rockSize, temperatureFirstHalfPlanetRotation
# ### magmaConcentrationDistance vs temperatureSecondHalfPlanetRotation, waterStreamDistanceX, waterStreamDistanceY
# ## mineralDensity
# ### mineralDensity vs cover, detectionDepth, geoZone, id, longitude
# ### mineralDensity vs magmaConcentrationDistance, mineralType, planetSection, rockSize, temperatureFirstHalfPlanetRotation
# ### mineralDensity vs temperatureSecondHalfPlanetRotation, waterStreamDistanceX, waterStreamDistanceY
# ## mineralType
# ### mineralType vs cover, detectionDepth, geoZone, id, longitude
# ### mineralType vs magmaConcentrationDistance, mineralDensity, planetSection, rockSize, temperatureFirstHalfPlanetRotation
# ### mineralType vs temperatureSecondHalfPlanetRotation, waterStreamDistanceX, waterStreamDistanceY
# ## planetSection
# ### planetSection vs cover, detectionDepth, geoZone, id, longitude
# ### planetSection vs magmaConcentrationDistance, mineralDensity, mineralType, rockSize, temperatureFirstHalfPlanetRotation
# ### planetSection vs temperatureSecondHalfPlanetRotation, waterStreamDistanceX, waterStreamDistanceY
# ## rockSize
# ### rockSize vs cover, detectionDepth, geoZone, id, longitude
# ### rockSize vs magmaConcentrationDistance, mineralDensity, mineralType, planetSection, temperatureFirstHalfPlanetRotation
# ### rockSize vs temperatureSecondHalfPlanetRotation, waterStreamDistanceX, waterStreamDistanceY
# ## temperatureFirstHalfPlanetRotation
# ### temperatureFirstHalfPlanetRotation vs cover, detectionDepth, geoZone, id, longitude
# ### temperatureFirstHalfPlanetRotation vs magmaConcentrationDistance, mineralDensity, mineralType, planetSection, rockSize
# ### temperatureFirstHalfPlanetRotation vs temperatureSecondHalfPlanetRotation, waterStreamDistanceX, waterStreamDistanceY
# ## temperatureSecondHalfPlanetRotation
# ### temperatureSecondHalfPlanetRotation vs cover, detectionDepth, geoZone, id, longitude
# ### temperatureSecondHalfPlanetRotation vs magmaConcentrationDistance, mineralDensity, mineralType, planetSection, rockSize
# ### temperatureSecondHalfPlanetRotation vs temperatureFirstHalfPlanetRotation, waterStreamDistanceX, waterStreamDistanceY
# ## waterStreamDistanceX
# ### waterStreamDistanceX vs cover, detectionDepth, geoZone, id, longitude
# ### waterStreamDistanceX vs magmaConcentrationDistance, mineralDensity, mineralType, planetSection, rockSize
# ### waterStreamDistanceX vs temperatureFirstHalfPlanetRotation, temperatureSecondHalfPlanetRotation, waterStreamDistanceY
# ## waterStreamDistanceY
# ### waterStreamDistanceY vs cover, detectionDepth, geoZone, id, longitude
# ### waterStreamDistanceY vs magmaConcentrationDistance, mineralDensity, mineralType, planetSection, rockSize
# ### waterStreamDistanceY vs temperatureFirstHalfPlanetRotation, temperatureSecondHalfPlanetRotation, waterStreamDistanceX
